# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os
import logging
from glob import glob

df = pd.read_csv('../data/preprocessed.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184349 entries, 0 to 184348
# Data columns (total 31 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   place         184349 non-null  int64
#  1   catu          184349 non-null  int64
#  2   grav          184349 non-null  int64
#  3   sexe          184349 non-null  int64
#  4   secu1         184349 non-null  float64
#  5   id_usager     129649 non-null  object
#  6   year_acc      184349 non-null  int64
#  7   victim_age    184347 non-null  float64
#  8   catv          184349 non-null  float64
#  9   obsm          184349 non-null  float64
#  10  motor         175800 non-null  float64
#  11  catr          184349 non-null  int64
#  12  circ          172940 non-null  float64
#  13  surf          184325 non-null  float64
#  14  situ          184326 non-null  float64
#  15  vma           184349 non-null  float64
#  16  jour          184349 non-null  float64
#  17  mois          184349 non-null  float64
#  18  lum           184349 non-null  float64
#  19  dep           184349 non-null  float64
#  20  com           184349 non-null  float64
#  21  agg_          184349 non-null  float64
#  22  int           184349 non-null  float64
#  23  atm           184349 non-null  float64
#  24  col           184309 non-null  float64
#  25  lat           184349 non-null  float64
#  26  long          184349 non-null  float64
#  27  Accident_Id   0 non-null       float64
#  28  hour          184349 non-null  float64
#  29  nb_victim     184349 non-null  int64
#  30  nb_vehicules  184349 non-null  int64
# dtypes: float64(22), int64(8), object(1)
# memory usage: 43.6+ MB

# %%
print(df['grav'].value_counts(normalize=True) * 100)
df['grav'].hist()
# Out:
# grav
# 0    65.930924
# 1    34.069076
# Name: proportion, dtype: float64
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

missing = df.isnull().mean() * 100
missing = missing[missing > 0].sort_values(ascending=False)
print(missing)
sns.heatmap(df.isnull(), cbar=False)
# Out:
# Accident_Id    100.000000
# id_usager       29.671981
# circ             6.188805
# motor            4.637400
# col              0.021698
# surf             0.013019
# situ             0.012476
# victim_age       0.001085
# dtype: float64
# <Axes: >

# %%
plt.figure(figsize=(20, 16))
sns.heatmap(df.select_dtypes(include=[np.number]).corr(), annot=True, cmap='coolwarm', fmt=".1f")
plt.show()
